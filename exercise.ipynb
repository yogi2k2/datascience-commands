# %%
"""Let us assume the dataset consists of 5 columns namely rollno , name , dept , location and mark .
Write the code for the following"""
# Out:
# 'Let us assume the dataset consists of 5 columns namely rollno , name , dept , location and mark .\nWrite the code for the following'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#creating a dataset
ds=pd.DataFrame({'rollno':[130,131,132,133,134],
                 'name':['ab','ac','ty','dy','uj'],
                 'dept':['cse','ece','eee','it','csbs'],
                 'mark':[100,99,98,97,96],
                'location':['pondy','chennai','thiruvallur','mahabalipuram','korattur']})

# %%
ds
# Out:
#    rollno name  dept  mark       location
# 0     130   ab   cse   100          pondy
# 1     131   ac   ece    99        chennai
# 2     132   ty   eee    98    thiruvallur
# 3     133   dy    it    97  mahabalipuram
# 4     134   uj  csbs    96       korattur

# %%
#display first 5 rows
ds.head()
# Out:
#    rollno name  dept  mark       location
# 0     130   ab   cse   100          pondy
# 1     131   ac   ece    99        chennai
# 2     132   ty   eee    98    thiruvallur
# 3     133   dy    it    97  mahabalipuram
# 4     134   uj  csbs    96       korattur

# %%
#display last 5 rows
ds.tail()
# Out:
#    rollno name  dept  mark       location
# 0     130   ab   cse   100          pondy
# 1     131   ac   ece    99        chennai
# 2     132   ty   eee    98    thiruvallur
# 3     133   dy    it    97  mahabalipuram
# 4     134   uj  csbs    96       korattur

# %%
#display 1st two rows
ds.head(2)
# Out:
#    rollno name dept  mark location
# 0     130   ab  cse   100    pondy
# 1     131   ac  ece    99  chennai

# %%
#last 2 rows
ds.tail(2)
# Out:
#    rollno name  dept  mark       location
# 3     133   dy    it    97  mahabalipuram
# 4     134   uj  csbs    96       korattur

# %%
#rename operation
ds.rename(columns={'rollno':'regno'})
# Out:
#    regno name  dept  mark       location
# 0    130   ab   cse   100          pondy
# 1    131   ac   ece    99        chennai
# 2    132   ty   eee    98    thiruvallur
# 3    133   dy    it    97  mahabalipuram
# 4    134   uj  csbs    96       korattur

# %%
#deleting operation
ds.drop(columns=['location'])
# Out:
#    rollno name  dept  mark
# 0     130   ab   cse   100
# 1     131   ac   ece    99
# 2     132   ty   eee    98
# 3     133   dy    it    97
# 4     134   uj  csbs    96

# %%
#displaying the mark range greater than 80 and less than 95
